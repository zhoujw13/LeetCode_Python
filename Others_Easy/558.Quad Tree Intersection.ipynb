# %%
# 558.Quad Tree Intersection

# %%
'''
# Definition for a QuadTree node.
class Node:
    def __init__(self, val, isLeaf, topLeft, topRight, bottomLeft, bottomRight):
        self.val = val
        self.isLeaf = isLeaf
        self.topLeft = topLeft
        self.topRight = topRight
        self.bottomLeft = bottomLeft
        self.bottomRight = bottomRight
'''
class Solution:
    def intersect(self, quadTree1, quadTree2):
        """
        :type quadTree1: Node
        :type quadTree2: Node
        :rtype: Node
        """
        
        if quadTree1==None:
            return quadTree2
        elif quadTree2==None:
            return quadTree1
        else:
            if quadTree1.val=='T' or quadTree2.val=='T':
                return Node('T',True, None,None,None,None)
            
            elif quadTree1.val=='F' and quadTree2=='F':
                return Node('F',True,None,None,None,None)
            
            elif quadTree1.val =='F' and quadTree2.isLeaf==False:
                return quadTree2
            
            elif quadTree1.isLeaf==False and quadTree2.val=='F':
                return quadTree1
            
            elif (quadTree1.topLeft.val=='T' or quadTree2.topLeft.val=='T') and (quadTree1.topRight.val=='T' or quadTree2.topRight.val=='T') and (quadTree1.bottomLeft.val=='T' or quadTree2.bottomLeft.val=='T') and (quadTree1.bottomRight.val=='T' or quadTree2.bottomRight.val=='T'):
                return Node('T',True,None,None,None,None)
            
            else:
                return Node('*',False,self.intersect(quadTree1.topLeft,quadTree2.topLeft),self.intersect(quadTree1.topRight,quadTree2.topRight),self.intersect(quadTree1.bottomLeft,quadTree2.bottomLeft),self.intersect(quadTree1.bottomRight,quadTree2.bottomRight))

# %%
'''
# Definition for a QuadTree node.
class Node:
    def __init__(self, val, isLeaf, topLeft, topRight, bottomLeft, bottomRight):
        self.val = val
        self.isLeaf = isLeaf
        self.topLeft = topLeft
        self.topRight = topRight
        self.bottomLeft = bottomLeft
        self.bottomRight = bottomRight
'''
class Solution:
    def intersect(self, quadTree1, quadTree2):
        """
        :type quadTree1: Node
        :type quadTree2: Node
        :rtype: Node
        """
        
        if quadTree1==None:
            return quadTree2
        elif quadTree2==None:
            return quadTree1
        
        else:
            if quadTree1.val=='T' or quadTree2.val=='T':
                return Node('T',True, None,None,None,None)
            
            elif quadTree1.val=='F' and quadTree2=='F':
                return Node('F',True,None,None,None,None)
            
            elif quadTree1.val =='F' and quadTree2.isLeaf==False:
                return quadTree2
            
            elif quadTree1.isLeaf==False and quadTree2.val=='F':
                return quadTree1
            
            elif quadTree1.topLeft!=None and quadTree2.topLeft!=None and (quadTree1.topLeft.val=='T' or quadTree2.topLeft.val=='T') and (quadTree1.topRight.val=='T' or quadTree2.topRight.val=='T') and (quadTree1.bottomLeft.val=='T' or quadTree2.bottomLeft.val=='T') and (quadTree1.bottomRight.val=='T' or quadTree2.bottomRight.val=='T'):
                return Node('T',True,None,None,None,None)
            
            else:
                return Node('*',False,self.intersect(quadTree1.topLeft,quadTree2.topLeft),self.intersect(quadTree1.topRight,quadTree2.topRight),self.intersect(quadTree1.bottomLeft,quadTree2.bottomLeft),self.intersect(quadTree1.bottomRight,quadTree2.bottomRight))
            
        # 有错误！！不知道错在哪里。。。。。

# %%
'''
# Definition for a QuadTree node.
class Node:
    def __init__(self, val, isLeaf, topLeft, topRight, bottomLeft, bottomRight):
        self.val = val
        self.isLeaf = isLeaf
        self.topLeft = topLeft
        self.topRight = topRight
        self.bottomLeft = bottomLeft
        self.bottomRight = bottomRight
'''
class Solution:
    def intersect(self, quadTree1, quadTree2):
        """
        :type quadTree1: Node
        :type quadTree2: Node
        :rtype: Node
        """
        
        if quadTree1==None:
            return quadTree2
        elif quadTree2==None:
            return quadTree1
        
        else:
            if quadTree1.val=='T' or quadTree2.val=='T':
                return Node('T',True, None,None,None,None)
            
            elif quadTree1.val=='F' and quadTree2=='F':
                return Node('F',True,None,None,None,None)
            
            elif quadTree1.val =='F' and quadTree2.isLeaf==False:
                return quadTree2
            
            elif quadTree1.isLeaf==False and quadTree2.val=='F':
                return quadTree1
            
            else:
                return Node('*',False,self.intersect(quadTree1.topLeft,quadTree2.topLeft),self.intersect(quadTree1.topRight,quadTree2.topRight),self.intersect(quadTree1.bottomLeft,quadTree2.bottomLeft),self.intersect(quadTree1.bottomRight,quadTree2.bottomRight))
            
        # 有错误！！还是要把相同四宫格合并起来

# %% [markdown]
# 【LeetCode】558. Quad Tree Intersection 解题报告（Python）
#
# https://blog.csdn.net/fuxuemingzhu/article/details/82356008
#
# 树的题目一般都是用递归来做。这个题有意思的地方在于，需要进行节点的合并操作。
#
# 首先，可以做个简单的递归分析：如果一个节点是True，那么无论和什么样的节点进行或运算都是True.如果一个节点是False，那么无论和什么样的节点进行或运算都是什么样的节点。
#
# 新节点的四个分叉都分别进行或运算即可。最后判断如果四个分叉都是同样的数值，那么就合并。
#
# 这里体现了这个题目有意思的地方，并不需要输出结果和答案完全一致。答案判定的规则是，如果某节点是叶子节点就不去判断它的四个分叉了，所以我的输出里四个分叉没有设置为None，但是都同样通过了。另外，如果一个节点不是叶子节点的话，就不去判断它的val了。
#
# 这样的检测方法省了不少事，代码里面就没有写置None的过程。

# %%
'''
# Definition for a QuadTree node.
class Node:
    def __init__(self, val, isLeaf, topLeft, topRight, bottomLeft, bottomRight):
        self.val = val
        self.isLeaf = isLeaf
        self.topLeft = topLeft
        self.topRight = topRight
        self.bottomLeft = bottomLeft
        self.bottomRight = bottomRight
'''
class Solution:
    def intersect(self, quadTree1, quadTree2):
        """
        :type quadTree1: Node
        :type quadTree2: Node
        :rtype: Node
        """
        
        if quadTree1.isLeaf:
            return quadTree1 if quadTree1.val else quadTree2
        if quadTree2.isLeaf:
            return quadTree2 if quadTree2.val else quadTree1
        
        a = self.intersect(quadTree1.topLeft,quadTree2.topLeft)
        b = self.intersect(quadTree1.topRight,quadTree2.topRight)
        c = self.intersect(quadTree1.bottomLeft,quadTree2.bottomLeft)
        d = self.intersect(quadTree1.bottomRight,quadTree2.bottomRight)
        
        if a.isLeaf and b.isLeaf and c.isLeaf and d.isLeaf:
            if a.val==b.val==c.val==d.val:
                return a
        return Node('*',False,a,b,c,d)

# %% [markdown]
# 这次对了！！我有一种这样的领悟：尽量把分情况讨论的事情留给电脑，而不要自己去想，让电脑多去模拟，自己少分情况！！！
